# %% [markdown]
# # Import

# %%
import os
import numpy as np
import tensorflow as tf
import time


from matplotlib import pyplot as plt
# %matplotlib inline

if 'COLAB_TPU_ADDR' not in os.environ:
    print('ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!')
else:
    tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
    print ('TPU address is', tpu_address)

    with tf.Session(tpu_address) as session:
        devices = session.list_devices()

    print('TPU devices:')
    for d in devices:
        print(d)
# Out:
# TPU address is grpc://10.73.80.10:8470
# TPU devices:
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 8547561617843128079)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 15808477494867059848)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 12623579180533311753)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 1913984400030128670)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 17589331628087456959)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 11177981104279709949)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 1820746118815596828)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 8848899767820247928)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 1444162556629070006)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 8270880794644059959)
# _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 2829608992864068866)

# %% [markdown]
# # Connect

# %%
import json
bucket = 'kurnianggoro ' #@param {type:"string"}

assert bucket, 'Must specify an existing GCS bucket name'
print('Using bucket: {}'.format(bucket))


from google.colab import auth
auth.authenticate_user()

TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])

# Upload credentials to TPU.
with tf.Session(TF_MASTER) as sess:    
    with open('/content/adc.json', 'r') as f:
        auth_info = json.load(f)
    tf.contrib.cloud.configure_gcs(sess, credentials=auth_info)
    # Now credentials are set for all future sessions on this TPU.
# Out:
# Using bucket: kurnianggoro
# WARNING: Logging before flag parsing goes to stderr.
# W0710 03:48:26.125220 139906365589376 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# # Dataset

# %% [markdown]
# ## augmentation

# %%
def data_augmentation(image, size=112):

    with tf.name_scope('DataAugmentation'):
        image = tf.cast(image, dtype=tf.float32)
        image = tf.image.random_flip_left_right(image)
        image = tf.image.resize_images(image,[size,size])
                
    return image

# %% [markdown]
# ## Parse

# %%
def parser_fn(example):
    features_format = {
        'image': tf.FixedLenFeature([], dtype= tf.string),
        'width': tf.FixedLenFeature([], dtype= tf.int64),
        'height': tf.FixedLenFeature([], dtype= tf.int64),
        'label': tf.FixedLenFeature([], dtype=tf.int64),
    }
    features = tf.parse_single_example(example, features_format)
    image = tf.image.decode_image(features['image'], channels=3)
    
    image = data_augmentation(image)
    return image, features['label']

def input_pipeline(params):
    data_path = params['data_path']
    batch_size = params['batch_size']
    data_format ='channels_last'
    
    data_files = tf.data.Dataset.list_files(data_path)
        

    dataset = tf.data.TFRecordDataset(data_files, num_parallel_reads=8)
    dataset = dataset.shuffle(16000)
    dataset = dataset.repeat().cache()
    dataset = dataset.map(parser_fn,num_parallel_calls=16)
    dataset = dataset.batch(batch_size)
        
    iterator = dataset.make_one_shot_iterator()
    
    features = iterator.get_next()
    image = features[0]
    label = features[1]
    
    image_size = params['train_image_size']
    
    if data_format=='channels_first':
        image.set_shape([batch_size,3,image_size,image_size])
    else:
        image.set_shape([batch_size,image_size,image_size, 3])
    label.set_shape([batch_size])
    
    return image,label

# %% [markdown]
# # Base Network

# %% [markdown]
# # VGG 16

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.slim.nets as nets

import numpy as np

slim = tf.contrib.slim

def vgg_arg_scope(weight_decay=0.0005):
    """Defines the VGG arg scope.
    Args:
    weight_decay: The l2 regularization coefficient.
    Returns:
    An arg_scope.
    """
    with slim.arg_scope([slim.conv2d, slim.fully_connected],
                      activation_fn=tf.nn.relu,
                      weights_regularizer=slim.l2_regularizer(weight_decay),
                      biases_initializer=tf.zeros_initializer()):
        with slim.arg_scope([slim.conv2d,slim.max_pool2d], padding='SAME') as arg_sc:
            return arg_sc

def vgg_16(inputs,
           num_classes=1000,
           is_training=True,
           dropout_keep_prob=0.5,
           spatial_squeeze=True,
           scope='vgg_16',
           fc_conv_padding='VALID',
           global_pool=False,
           reuse = False,
           final_endpoint='fc8'):

    end_points = {}
    def add_and_check_final(name, net, collection):
        end_points = slim.utils.convert_collection_to_dict(collection)
        return name == final_endpoint

    with tf.variable_scope(scope, 'vgg_16', [inputs], reuse=reuse) as sc:
        end_points_collection = sc.original_name_scope + '_end_points'
        # Collect outputs for conv2d, fully_connected and max_pool2d.
        with slim.arg_scope([slim.conv2d, slim.fully_connected, slim.max_pool2d],
                            outputs_collections=end_points_collection):
            net = slim.repeat(inputs, 2, slim.conv2d, 64, [3, 3], scope='conv1')
            if ('conv1'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.max_pool2d(net, [2, 2], scope='pool1')
            if ('pool1'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2')
            if ('conv2'==final_endpoint):
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.max_pool2d(net, [2, 2], scope='pool2')
            if ('pool2'==final_endpoint):
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.repeat(net, 3, slim.conv2d, 256, [3, 3], scope='conv3')
            if ('conv3'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.max_pool2d(net, [2, 2], scope='pool3')
            if ('pool3'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.repeat(net, 3, slim.conv2d, 512, [3, 3], scope='conv4')
            if ('conv4'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.max_pool2d(net, [2, 2], scope='pool4')
            if ('pool4'==final_endpoint):
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.repeat(net, 3, slim.conv2d, 512, [3, 3], scope='conv5')
            if ('conv5'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.max_pool2d(net, [2, 2], stride=2,scope='pool5')
            if ('pool5'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            # Use conv2d instead of fully_connected layers.
            net = slim.conv2d(net, 4096, [7, 7], padding=fc_conv_padding, scope='fc6')
            if ('fc6'==final_endpoint):
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                             scope='dropout6')
            net = slim.conv2d(net, 4096, [1, 1], scope='fc7')
            if ('fc7'==final_endpoint): 
                end_points = slim.utils.convert_collection_to_dict(end_points_collection)
                return net, end_points
            
            # Convert end_points_collection into a end_point dict.
            end_points = slim.utils.convert_collection_to_dict(end_points_collection)
            if global_pool:
                net = tf.reduce_mean(net, [1, 2], keep_dims=True, name='global_pool')
                end_points['global_pool'] = net
            if num_classes:
                net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                                   scope='dropout7')
                net = slim.conv2d(net, num_classes, [1, 1],
                                  activation_fn=None,
                                  normalizer_fn=None,
                                  scope='fc8')
                if spatial_squeeze:
                    net = tf.squeeze(net, [1, 2], name='fc8/squeezed')
                end_points[sc.name + '/fc8'] = net
                
            return net, end_points

vgg_16.default_image_size = 224
vgg_16.R_MEAN = 123.
vgg_16.G_MEAN = 117.
vgg_16.B_MEAN = 104.

# %% [markdown]
# #Model

# %% [markdown]
# ##Initializer

# %%
def basenet_initializer(pretrained_vars, scope_in_model, scope_in_ckpt, checkpoint_path):
    #make the pairs of var_names and vars, var_names must match the names in ckpt
    variables_to_restore = {var.op.name.replace(scope_in_model, scope_in_ckpt): var for var in pretrained_vars}

    loader = tf.train.Saver(variables_to_restore)
    loader.build()       

    def callback(scaffold, session):
        loader.restore(session, checkpoint_path)
        
    return callback

# %% [markdown]
# # Base Model

# %%
def model(inputs, n_class, reuse=tf.AUTO_REUSE):
    start_vars = set(x.name for x in tf.global_variables())
    with slim.arg_scope(vgg_arg_scope()):
        net, vgg_layers = vgg_16(inputs, 1000, is_training=True, reuse=reuse, final_endpoint='pool5')
    end_vars = tf.global_variables()
    basenet_vars = [x for x in end_vars if x.name not in start_vars]
    
    emb = tf.layers.conv2d(net, 512,(4,4), activation=tf.nn.relu, name='embeddings')
    logits = tf.layers.conv2d(emb, n_class,(1,1), activation=tf.nn.relu)
    logits = tf.reshape(logits, [-1,n_class], name='logits')
    
    return logits, basenet_vars

# %% [markdown]
# ## TPU Model

# %%
def tpu_model(features, labels, mode, params):
    with tf.variable_scope(params['model_scope'], reuse=tf.AUTO_REUSE):
        logits, basenet_vars = model(features, params['num_classes'], reuse=tf.AUTO_REUSE)

    predictions = tf.argmax(logits, axis=-1)
    
    print('-'*50)
    for v in tf.global_variables():
        print(v)
    print('-'*50)
    
    with tf.name_scope('Losses'):
        with tf.name_scope('softmax_loss'):
            loss = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels)
            softmax_loss = tf.reduce_mean(loss)

        l2_loss_vars = []
        with tf.name_scope('regularizer'):
            for trainable_var in tf.trainable_variables():
                l2_loss_vars.append(tf.nn.l2_loss(trainable_var))
        l2_loss = tf.multiply(params['weight_decay'], tf.add_n(l2_loss_vars), name='l2_loss')
        
        with tf.name_scope('total_loss'):
            total_loss = tf.add(softmax_loss, l2_loss, name='total_loss')
    
    with tf.name_scope('Optimizer'):
        global_step = tf.train.get_or_create_global_step()
        
        optimizer = tf.train.MomentumOptimizer(learning_rate=params['learning_rate'], momentum=params['momentum'])

        if params['use_tpu']:
            optimizer = tf.contrib.tpu.CrossShardOptimizer(optimizer, tf.losses.Reduction.MEAN)

        train_op = optimizer.minimize(total_loss, global_step)   
    
    def scaffold_fn():    
        return tf.train.Scaffold(init_fn=basenet_initializer(basenet_vars, flags['model_scope']+'/vgg_16', 'vgg_16', params['checkpoint_path']))
    
    return tf.contrib.tpu.TPUEstimatorSpec(
                              mode=mode,
                              predictions=predictions,
                              loss=total_loss,
                              train_op=train_op,
                              scaffold_fn=scaffold_fn
                    )

# %% [markdown]
# # Training

# %%
tf.reset_default_graph()
tf.logging.set_verbosity(tf.logging.INFO)

flags = {}
flags['train_image_size'] = 112
flags['data_path'] = 'gs://kurnianggoro/casia112_tfrecord/train-*'
flags['model_dir'] = 'gs://kurnianggoro/training/testvgg/'
flags['save_checkpoints_secs'] = 60
flags['save_summary_steps'] = 500
flags['tf_random_seed'] = 54334
flags['log_every_n_steps'] = 100

flags['batch_size_base'] = 512

flags['model_scope'] = 'VGGmodel'
flags['weight_decay'] = 5e-4
flags['momentum'] = 0.9
flags['learning_rate'] = 1e-3
flags['checkpoint_path'] = 'gs://kurnianggoro/vgg16_standard/vgg_16.ckpt'
flags['num_classes'] = 10572

flags['train_image_size'] = 112
flags['max_number_of_steps'] = 30000

for k,v in flags.items():
    print(k,v)

config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=False, 
                        #intra_op_parallelism_threads=flags['num_cpu_threads'], 
                        #inter_op_parallelism_threads=flags['num_cpu_threads'], 
                        )


tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(tpu_address,)

# Set up a RunConfig to only save checkpoints once per training cycle.
run_config =  tf.contrib.tpu.RunConfig(cluster=tpu_cluster_resolver,model_dir=flags['model_dir']).replace(
                                    save_checkpoints_secs=flags['save_checkpoints_secs']).replace(
                                    save_checkpoints_steps=None).replace(
                                    save_summary_steps=flags['save_summary_steps']).replace(
                                    keep_checkpoint_max=5).replace(
                                    tf_random_seed=flags['tf_random_seed']).replace(
                                    log_step_count_steps=flags['log_every_n_steps']).replace(
                                    session_config=config,
                                    tpu_config=tf.contrib.tpu.TPUConfig(100, 8)
                                    )

trainer = tf.contrib.tpu.TPUEstimator(
    model_fn=tpu_model, use_tpu=True, model_dir=flags['model_dir'], config=run_config,train_batch_size=flags['batch_size_base'],
    params={
        'model_scope': flags['model_scope'],
        'num_classes': flags['num_classes'],
        'weight_decay': flags['weight_decay'],
        'momentum': flags['momentum'],
        'learning_rate': flags['learning_rate'],
        'checkpoint_path': flags['checkpoint_path'],
        'data_path': flags['data_path'],
        'is_training': True,
        'train_image_size': flags['train_image_size']
        
    })


print('Starting a training cycle.')
trainer.train(input_fn=input_pipeline,
                   max_steps=flags['max_number_of_steps'],
#                    steps=1000
                  )
# Out:
# train_image_size 112
# data_path gs://kurnianggoro/casia112_tfrecord/train-*
# model_dir gs://kurnianggoro/training/testvgg/
# save_checkpoints_secs 60
# save_summary_steps 500
# tf_random_seed 54334
# log_every_n_steps 100
# batch_size_base 512
# model_scope VGGmodel
# weight_decay 0.0005
# momentum 0.9
# learning_rate 0.001
# checkpoint_path gs://kurnianggoro/vgg16_standard/vgg_16.ckpt
# num_classes 10572
# max_number_of_steps 30000
# I0710 03:50:53.822002 139906365589376 estimator.py:209] Using config: {'_model_dir': 'gs://kurnianggoro/training/testvgg/', '_tf_random_seed': 54334, '_save_summary_steps': 500, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 60, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3e32a24748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://10.73.80.10:8470', '_evaluation_master': 'grpc://10.73.80.10:8470', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=100, num_shards=8, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2), '_cluster': <tensorflow.python.distribute.cluster_resolver.tpu_cluster_resolver.TPUClusterResolver object at 0x7f3e32a244e0>}
# I0710 03:50:53.823379 139906365589376 tpu_context.py:209] _TPUContext: eval_on_tpu True
# Starting a training cycle.
# I0710 03:50:54.488768 139906365589376 tpu_system_metadata.py:78] Querying Tensorflow master (grpc://10.73.80.10:8470) for TPU system metadata.
# I0710 03:50:54.497261 139906365589376 tpu_system_metadata.py:148] Found TPU system:
# I0710 03:50:54.498866 139906365589376 tpu_system_metadata.py:149] *** Num TPU Cores: 8
# I0710 03:50:54.505394 139906365589376 tpu_system_metadata.py:150] *** Num TPU Workers: 1
# I0710 03:50:54.506703 139906365589376 tpu_system_metadata.py:152] *** Num TPU Cores Per Worker: 8
# I0710 03:50:54.507949 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 8547561617843128079)
# I0710 03:50:54.510479 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 12623579180533311753)
# I0710 03:50:54.512295 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 1913984400030128670)
# I0710 03:50:54.513817 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 17589331628087456959)
# I0710 03:50:54.515657 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 11177981104279709949)
# I0710 03:50:54.517178 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 1820746118815596828)
# I0710 03:50:54.519514 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 8848899767820247928)
# I0710 03:50:54.521629 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 1444162556629070006)
# I0710 03:50:54.523174 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 8270880794644059959)
# I0710 03:50:54.524845 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 2829608992864068866)
# I0710 03:50:54.526553 139906365589376 tpu_system_metadata.py:154] *** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 15808477494867059848)
# I0710 03:50:54.554972 139906365589376 estimator.py:1145] Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Seed 54334 from outer graph might be getting used by function Dataset_map_parser_fn, if the random op has not been provided any seed. Explicitly set the seed in the function if this is not the intended behavior.
# --------------------------------------------------
# <tf.Variable 'global_step:0' shape=() dtype=int64>
# <tf.Variable 'VGGmodel/vgg_16/conv1/conv1_1/weights:0' shape=(3, 3, 3, 64) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv1/conv1_1/biases:0' shape=(64,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv1/conv1_2/weights:0' shape=(3, 3, 64, 64) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv1/conv1_2/biases:0' shape=(64,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv2/conv2_1/weights:0' shape=(3, 3, 64, 128) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv2/conv2_1/biases:0' shape=(128,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv2/conv2_2/weights:0' shape=(3, 3, 128, 128) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv2/conv2_2/biases:0' shape=(128,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_1/weights:0' shape=(3, 3, 128, 256) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_1/biases:0' shape=(256,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_2/weights:0' shape=(3, 3, 256, 256) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_2/biases:0' shape=(256,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_3/weights:0' shape=(3, 3, 256, 256) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv3/conv3_3/biases:0' shape=(256,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_1/weights:0' shape=(3, 3, 256, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_1/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_2/weights:0' shape=(3, 3, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_2/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_3/weights:0' shape=(3, 3, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv4/conv4_3/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_1/weights:0' shape=(3, 3, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_1/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_2/weights:0' shape=(3, 3, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_2/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_3/weights:0' shape=(3, 3, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/vgg_16/conv5/conv5_3/biases:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/embeddings/kernel:0' shape=(4, 4, 512, 512) dtype=float32>
# <tf.Variable 'VGGmodel/embeddings/bias:0' shape=(512,) dtype=float32>
# <tf.Variable 'VGGmodel/conv2d/kernel:0' shape=(1, 1, 512, 10572) dtype=float32>
# <tf.Variable 'VGGmodel/conv2d/bias:0' shape=(10572,) dtype=float32>
# --------------------------------------------------
# I0710 03:50:57.291239 139906365589376 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0710 03:50:57.356161 139906365589376 estimator.py:1147] Done calling model_fn.
# I0710 03:50:57.357641 139906365589376 tpu_estimator.py:499] TPU job name tpu_worker
# I0710 03:50:57.596233 139906365589376 monitored_session.py:240] Graph was finalized.
# I0710 03:50:57.647992 139906365589376 saver.py:1280] Restoring parameters from gs://kurnianggoro/training/testvgg/model.ckpt-0
# W0710 03:51:00.168092 139906365589376 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0710 03:51:00.406972 139906365589376 session_manager.py:500] Running local_init_op.
# I0710 03:51:00.497389 139906365589376 session_manager.py:502] Done running local_init_op.
# I0710 03:51:02.059696 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 0 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:51:08.002460 139906365589376 util.py:98] Initialized dataset iterators in 0 seconds
# I0710 03:51:08.003762 139906365589376 session_support.py:332] Installing graceful shutdown hook.
# I0710 03:51:08.013362 139906365589376 session_support.py:82] Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# I0710 03:51:08.017560 139906365589376 session_support.py:105] Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# I0710 03:51:08.023564 139906365589376 tpu_estimator.py:557] Init TPU system
# I0710 03:51:12.776628 139906365589376 tpu_estimator.py:566] Initialized TPU in 4 seconds
# I0710 03:51:12.778397 139905078650624 tpu_estimator.py:514] Starting infeed thread controller.
# I0710 03:51:12.779032 139905070257920 tpu_estimator.py:533] Starting outfeed thread controller.
# I0710 03:51:12.861386 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:51:12.862582 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:51:25.214358 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (0, 0)
# I0710 03:51:36.005262 139906365589376 basic_session_run_hooks.py:262] loss = 9.382594, step = 100
# I0710 03:51:36.010161 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:51:36.012337 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:51:47.543117 139906365589376 basic_session_run_hooks.py:260] loss = 9.713073, step = 200 (11.538 sec)
# I0710 03:51:47.546433 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.66705
# I0710 03:51:47.945893 139906365589376 tpu_estimator.py:2160] examples/sec: 4437.53
# I0710 03:51:47.950261 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:51:47.955464 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:51:58.930865 139906365589376 basic_session_run_hooks.py:260] loss = 9.5650835, step = 300 (11.388 sec)
# I0710 03:51:58.933390 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.78194
# I0710 03:51:58.934897 139906365589376 tpu_estimator.py:2160] examples/sec: 4496.35
# I0710 03:51:58.945595 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:51:58.946728 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:52:10.004814 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:52:15.908042 139906365589376 basic_session_run_hooks.py:260] loss = 9.932435, step = 400 (16.977 sec)
# I0710 03:52:15.910698 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.89022
# I0710 03:52:15.912992 139906365589376 tpu_estimator.py:2160] examples/sec: 3015.79
# I0710 03:52:15.916559 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:52:15.918766 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:52:25.224541 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (4, 84)
# I0710 03:52:26.931689 139906365589376 basic_session_run_hooks.py:260] loss = 9.173834, step = 500 (11.024 sec)
# I0710 03:52:26.934296 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07146
# I0710 03:52:26.936263 139906365589376 tpu_estimator.py:2160] examples/sec: 4644.59
# I0710 03:52:26.938698 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:52:26.940507 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:52:37.987161 139906365589376 basic_session_run_hooks.py:260] loss = 9.896134, step = 600 (11.055 sec)
# I0710 03:52:37.989702 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.04532
# I0710 03:52:37.991870 139906365589376 tpu_estimator.py:2160] examples/sec: 4631.2
# I0710 03:52:38.000646 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:52:38.001820 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:52:48.962161 139906365589376 basic_session_run_hooks.py:260] loss = 9.543504, step = 700 (10.975 sec)
# I0710 03:52:48.964746 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.11159
# I0710 03:52:48.971975 139906365589376 tpu_estimator.py:2160] examples/sec: 4665.13
# I0710 03:52:48.975793 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:52:48.978210 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:52:59.954428 139906365589376 basic_session_run_hooks.py:260] loss = 9.771718, step = 800 (10.992 sec)
# I0710 03:52:59.956715 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09753
# I0710 03:52:59.959079 139906365589376 tpu_estimator.py:2160] examples/sec: 4657.93
# I0710 03:52:59.964836 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:52:59.966039 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:53:10.953028 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:53:16.585626 139906365589376 basic_session_run_hooks.py:260] loss = 9.545353, step = 900 (16.631 sec)
# I0710 03:53:16.588726 139906365589376 tpu_estimator.py:2159] global_step/sec: 6.01251
# I0710 03:53:16.589952 139906365589376 tpu_estimator.py:2160] examples/sec: 3078.41
# I0710 03:53:16.596425 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:53:16.597749 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:53:25.231249 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (9, 78)
# I0710 03:53:27.589198 139906365589376 basic_session_run_hooks.py:260] loss = 9.763496, step = 1000 (11.004 sec)
# I0710 03:53:27.595604 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08529
# I0710 03:53:27.601492 139906365589376 tpu_estimator.py:2160] examples/sec: 4651.67
# I0710 03:53:27.605168 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:53:27.606579 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:53:38.593982 139906365589376 basic_session_run_hooks.py:260] loss = 8.806267, step = 1100 (11.005 sec)
# I0710 03:53:38.597132 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08964
# I0710 03:53:38.598452 139906365589376 tpu_estimator.py:2160] examples/sec: 4653.9
# I0710 03:53:38.601625 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:53:38.604241 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:53:49.620633 139906365589376 basic_session_run_hooks.py:260] loss = 9.60765, step = 1200 (11.027 sec)
# I0710 03:53:49.623868 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.06886
# I0710 03:53:50.120452 139906365589376 tpu_estimator.py:2160] examples/sec: 4643.25
# I0710 03:53:50.129224 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:53:50.131075 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:54:01.164051 139906365589376 basic_session_run_hooks.py:260] loss = 8.62086, step = 1300 (11.543 sec)
# I0710 03:54:01.167203 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.663
# I0710 03:54:01.171471 139906365589376 tpu_estimator.py:2160] examples/sec: 4435.45
# I0710 03:54:01.178505 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:54:01.180393 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:54:12.165304 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 1400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:54:17.823626 139906365589376 basic_session_run_hooks.py:260] loss = 9.746875, step = 1400 (16.660 sec)
# I0710 03:54:17.828043 139906365589376 tpu_estimator.py:2159] global_step/sec: 6.00211
# I0710 03:54:17.831289 139906365589376 tpu_estimator.py:2160] examples/sec: 3073.08
# I0710 03:54:17.839272 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:54:17.840455 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:54:25.299632 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (14, 65)
# I0710 03:54:29.064007 139906365589376 basic_session_run_hooks.py:260] loss = 9.317707, step = 1500 (11.240 sec)
# I0710 03:54:29.066815 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.89775
# I0710 03:54:29.069426 139906365589376 tpu_estimator.py:2160] examples/sec: 4555.65
# I0710 03:54:29.072352 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:54:29.073526 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:54:40.031369 139906365589376 basic_session_run_hooks.py:260] loss = 8.809652, step = 1600 (10.967 sec)
# I0710 03:54:40.034404 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.11778
# I0710 03:54:40.035543 139906365589376 tpu_estimator.py:2160] examples/sec: 4668.31
# I0710 03:54:40.038788 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:54:40.041030 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:54:51.018502 139906365589376 basic_session_run_hooks.py:260] loss = 9.646205, step = 1700 (10.987 sec)
# I0710 03:54:51.021854 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10127
# I0710 03:54:51.025662 139906365589376 tpu_estimator.py:2160] examples/sec: 4659.85
# I0710 03:54:51.029284 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:54:51.030547 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:55:02.434298 139906365589376 basic_session_run_hooks.py:260] loss = 9.007468, step = 1800 (11.416 sec)
# I0710 03:55:02.437671 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.75979
# I0710 03:55:02.441173 139906365589376 tpu_estimator.py:2160] examples/sec: 4485.01
# I0710 03:55:02.448575 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:55:02.450624 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:55:13.424574 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 1900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:55:19.299323 139906365589376 basic_session_run_hooks.py:260] loss = 8.965005, step = 1900 (16.865 sec)
# I0710 03:55:19.302384 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.92953
# I0710 03:55:19.304624 139906365589376 tpu_estimator.py:2160] examples/sec: 3035.92
# I0710 03:55:19.307126 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:55:19.309514 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:55:25.363049 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (19, 54)
# I0710 03:55:30.323124 139906365589376 basic_session_run_hooks.py:260] loss = 9.089349, step = 2000 (11.024 sec)
# I0710 03:55:30.325476 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07186
# I0710 03:55:30.326791 139906365589376 tpu_estimator.py:2160] examples/sec: 4644.79
# I0710 03:55:30.329420 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:55:30.333591 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:55:41.367633 139906365589376 basic_session_run_hooks.py:260] loss = 8.479036, step = 2100 (11.045 sec)
# I0710 03:55:41.370000 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.05426
# I0710 03:55:41.372432 139906365589376 tpu_estimator.py:2160] examples/sec: 4635.78
# I0710 03:55:41.378349 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:55:41.379743 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:55:52.692383 139906365589376 basic_session_run_hooks.py:260] loss = 9.073454, step = 2200 (11.325 sec)
# I0710 03:55:52.695071 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.82997
# I0710 03:55:52.696697 139906365589376 tpu_estimator.py:2160] examples/sec: 4520.95
# I0710 03:55:52.702641 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:55:52.706912 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:56:03.686383 139906365589376 basic_session_run_hooks.py:260] loss = 8.806675, step = 2300 (10.994 sec)
# I0710 03:56:03.689572 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09545
# I0710 03:56:03.690995 139906365589376 tpu_estimator.py:2160] examples/sec: 4656.87
# I0710 03:56:03.696906 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:56:03.698441 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:56:14.793435 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 2400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# W0710 03:56:19.480031 139906365589376 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# I0710 03:56:20.679422 139906365589376 basic_session_run_hooks.py:260] loss = 9.142409, step = 2400 (16.993 sec)
# I0710 03:56:20.682538 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.8848
# I0710 03:56:20.686043 139906365589376 tpu_estimator.py:2160] examples/sec: 3013.02
# I0710 03:56:20.689265 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:56:20.691167 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:56:25.454994 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (24, 41)
# I0710 03:56:31.798211 139906365589376 basic_session_run_hooks.py:260] loss = 9.2720995, step = 2500 (11.119 sec)
# I0710 03:56:31.800783 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.99419
# I0710 03:56:31.802004 139906365589376 tpu_estimator.py:2160] examples/sec: 4605.02
# I0710 03:56:31.804787 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:56:31.806046 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:56:42.792444 139906365589376 basic_session_run_hooks.py:260] loss = 9.364254, step = 2600 (10.994 sec)
# I0710 03:56:42.795218 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.0955
# I0710 03:56:42.797149 139906365589376 tpu_estimator.py:2160] examples/sec: 4656.9
# I0710 03:56:42.801265 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:56:42.802560 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:56:54.261043 139906365589376 basic_session_run_hooks.py:260] loss = 9.10877, step = 2700 (11.469 sec)
# I0710 03:56:54.264394 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.71906
# I0710 03:56:54.265301 139906365589376 tpu_estimator.py:2160] examples/sec: 4464.16
# I0710 03:56:54.270987 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:56:54.272225 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:57:05.240151 139906365589376 basic_session_run_hooks.py:260] loss = 9.023329, step = 2800 (10.979 sec)
# I0710 03:57:05.248034 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10448
# I0710 03:57:05.250332 139906365589376 tpu_estimator.py:2160] examples/sec: 4661.49
# I0710 03:57:05.255525 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:57:05.257123 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:57:16.246507 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 2900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:57:22.606569 139906365589376 basic_session_run_hooks.py:260] loss = 8.864461, step = 2900 (17.366 sec)
# I0710 03:57:22.610831 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.75942
# I0710 03:57:22.612097 139906365589376 tpu_estimator.py:2160] examples/sec: 2948.82
# I0710 03:57:22.614098 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:57:22.615428 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:57:25.555734 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (29, 21)
# I0710 03:57:34.054739 139906365589376 basic_session_run_hooks.py:260] loss = 7.4877677, step = 3000 (11.448 sec)
# I0710 03:57:34.057978 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.7358
# I0710 03:57:34.060786 139906365589376 tpu_estimator.py:2160] examples/sec: 4472.73
# I0710 03:57:34.064053 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:57:34.065850 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:57:45.054578 139906365589376 basic_session_run_hooks.py:260] loss = 8.454461, step = 3100 (11.000 sec)
# I0710 03:57:45.058730 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09033
# I0710 03:57:45.060112 139906365589376 tpu_estimator.py:2160] examples/sec: 4654.25
# I0710 03:57:45.065223 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:57:45.066563 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:57:56.043170 139906365589376 basic_session_run_hooks.py:260] loss = 8.2969675, step = 3200 (10.989 sec)
# I0710 03:57:56.046297 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10114
# I0710 03:57:56.047229 139906365589376 tpu_estimator.py:2160] examples/sec: 4659.78
# I0710 03:57:56.425111 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:57:56.427191 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:58:07.739288 139906365589376 basic_session_run_hooks.py:260] loss = 9.118315, step = 3300 (11.696 sec)
# I0710 03:58:07.742243 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.54997
# I0710 03:58:07.743520 139906365589376 tpu_estimator.py:2160] examples/sec: 4377.58
# I0710 03:58:07.747123 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:58:07.749230 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:58:18.699401 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 3400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:58:25.243385 139906365589376 basic_session_run_hooks.py:260] loss = 9.069869, step = 3400 (17.504 sec)
# I0710 03:58:25.246683 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.71287
# I0710 03:58:25.248191 139906365589376 tpu_estimator.py:2160] examples/sec: 2924.99
# I0710 03:58:25.251127 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:58:25.252622 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:58:25.589730 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (34, 1)
# I0710 03:58:36.260475 139906365589376 basic_session_run_hooks.py:260] loss = 7.542466, step = 3500 (11.017 sec)
# I0710 03:58:36.263635 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07686
# I0710 03:58:36.268062 139906365589376 tpu_estimator.py:2160] examples/sec: 4647.35
# I0710 03:58:36.270822 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:58:36.271731 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:58:47.444193 139906365589376 basic_session_run_hooks.py:260] loss = 8.673216, step = 3600 (11.184 sec)
# I0710 03:58:47.447204 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.94167
# I0710 03:58:47.448314 139906365589376 tpu_estimator.py:2160] examples/sec: 4578.14
# I0710 03:58:47.454887 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:58:47.457601 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:58:58.426325 139906365589376 basic_session_run_hooks.py:260] loss = 8.6711235, step = 3700 (10.982 sec)
# I0710 03:58:58.429614 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10548
# I0710 03:58:58.432411 139906365589376 tpu_estimator.py:2160] examples/sec: 4662.01
# I0710 03:58:58.436936 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:58:58.437868 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:59:09.421579 139906365589376 basic_session_run_hooks.py:260] loss = 9.005621, step = 3800 (10.995 sec)
# I0710 03:59:09.424960 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09477
# I0710 03:59:09.426470 139906365589376 tpu_estimator.py:2160] examples/sec: 4656.52
# I0710 03:59:09.428802 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:59:09.432945 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:59:20.402347 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 3900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 03:59:26.816333 139906365589376 basic_session_run_hooks.py:260] loss = 8.381969, step = 3900 (17.395 sec)
# I0710 03:59:26.819538 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.7489
# I0710 03:59:26.822465 139906365589376 tpu_estimator.py:2160] examples/sec: 2943.44
# I0710 03:59:26.827992 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:59:26.829571 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:59:27.057972 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (39, 0)
# I0710 03:59:37.862647 139906365589376 basic_session_run_hooks.py:260] loss = 6.9666615, step = 4000 (11.046 sec)
# I0710 03:59:37.866851 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.05293
# I0710 03:59:37.869554 139906365589376 tpu_estimator.py:2160] examples/sec: 4635.1
# I0710 03:59:37.872665 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:59:37.874499 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:59:48.879061 139906365589376 basic_session_run_hooks.py:260] loss = 7.9216537, step = 4100 (11.016 sec)
# I0710 03:59:48.882835 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07681
# I0710 03:59:48.885223 139906365589376 tpu_estimator.py:2160] examples/sec: 4647.33
# I0710 03:59:48.887775 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 03:59:48.889058 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 03:59:59.858605 139906365589376 basic_session_run_hooks.py:260] loss = 7.116155, step = 4200 (10.980 sec)
# I0710 03:59:59.861768 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10834
# I0710 04:00:00.212821 139906365589376 tpu_estimator.py:2160] examples/sec: 4663.47
# I0710 04:00:00.216174 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:00:00.218676 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:00:11.204360 139906365589376 basic_session_run_hooks.py:260] loss = 8.395994, step = 4300 (11.346 sec)
# I0710 04:00:11.207010 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.81428
# I0710 04:00:11.208812 139906365589376 tpu_estimator.py:2160] examples/sec: 4512.91
# I0710 04:00:11.212498 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:00:11.214399 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:00:22.196181 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 4400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:00:28.561266 139906365589376 basic_session_run_hooks.py:260] loss = 7.753229, step = 4400 (17.357 sec)
# I0710 04:00:28.564064 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.76133
# I0710 04:00:28.568118 139906365589376 tpu_estimator.py:2160] examples/sec: 2949.8
# I0710 04:00:28.571368 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:00:28.575524 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:00:28.804780 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (44, 0)
# I0710 04:00:39.579193 139906365589376 basic_session_run_hooks.py:260] loss = 7.426322, step = 4500 (11.018 sec)
# I0710 04:00:39.581954 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07617
# I0710 04:00:39.587832 139906365589376 tpu_estimator.py:2160] examples/sec: 4647
# I0710 04:00:39.591294 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:00:39.593316 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:00:50.584020 139906365589376 basic_session_run_hooks.py:260] loss = 8.144618, step = 4600 (11.005 sec)
# I0710 04:00:50.588385 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08693
# I0710 04:00:50.590645 139906365589376 tpu_estimator.py:2160] examples/sec: 4652.51
# I0710 04:00:50.593674 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:00:50.595297 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:01:01.594509 139906365589376 basic_session_run_hooks.py:260] loss = 7.581389, step = 4700 (11.010 sec)
# I0710 04:01:01.597079 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08238
# I0710 04:01:01.599609 139906365589376 tpu_estimator.py:2160] examples/sec: 4650.18
# I0710 04:01:01.605914 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:01:01.607771 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:01:12.575119 139906365589376 basic_session_run_hooks.py:260] loss = 7.699293, step = 4800 (10.981 sec)
# I0710 04:01:12.577677 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10698
# I0710 04:01:12.579384 139906365589376 tpu_estimator.py:2160] examples/sec: 4662.78
# I0710 04:01:12.586369 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:01:12.588292 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:01:23.738246 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 4900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:01:30.236821 139906365589376 basic_session_run_hooks.py:260] loss = 7.255893, step = 4900 (17.662 sec)
# I0710 04:01:30.239282 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.66198
# I0710 04:01:30.240638 139906365589376 tpu_estimator.py:2160] examples/sec: 2898.94
# I0710 04:01:30.243589 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:01:30.245383 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:01:30.477799 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (49, 0)
# I0710 04:01:41.252036 139906365589376 basic_session_run_hooks.py:260] loss = 7.5426593, step = 5000 (11.015 sec)
# I0710 04:01:41.254669 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07819
# I0710 04:01:41.256576 139906365589376 tpu_estimator.py:2160] examples/sec: 4648.03
# I0710 04:01:41.264609 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:01:41.265601 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:01:52.242688 139906365589376 basic_session_run_hooks.py:260] loss = 7.065453, step = 5100 (10.991 sec)
# I0710 04:01:52.245245 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09874
# I0710 04:01:52.246627 139906365589376 tpu_estimator.py:2160] examples/sec: 4658.55
# I0710 04:01:52.250625 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:01:52.252827 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:02:03.247109 139906365589376 basic_session_run_hooks.py:260] loss = 7.7964745, step = 5200 (11.004 sec)
# I0710 04:02:03.253400 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08515
# I0710 04:02:03.625856 139906365589376 tpu_estimator.py:2160] examples/sec: 4651.6
# I0710 04:02:03.634846 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:02:03.640156 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:02:14.625094 139906365589376 basic_session_run_hooks.py:260] loss = 6.7040243, step = 5300 (11.378 sec)
# I0710 04:02:14.627596 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.79091
# I0710 04:02:14.629628 139906365589376 tpu_estimator.py:2160] examples/sec: 4500.95
# I0710 04:02:14.634315 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:02:14.636643 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:02:25.591830 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 5400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:02:32.131385 139906365589376 basic_session_run_hooks.py:260] loss = 6.394515, step = 5400 (17.506 sec)
# I0710 04:02:32.134015 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.71219
# I0710 04:02:32.136226 139906365589376 tpu_estimator.py:2160] examples/sec: 2924.64
# I0710 04:02:32.141591 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:02:32.143499 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:02:32.385558 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (54, 0)
# I0710 04:02:43.148304 139906365589376 basic_session_run_hooks.py:260] loss = 8.127487, step = 5500 (11.017 sec)
# I0710 04:02:43.150992 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07693
# I0710 04:02:43.152377 139906365589376 tpu_estimator.py:2160] examples/sec: 4647.39
# I0710 04:02:43.155676 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:02:43.157523 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:02:54.122116 139906365589376 basic_session_run_hooks.py:260] loss = 8.114915, step = 5600 (10.974 sec)
# I0710 04:02:54.124668 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.11269
# I0710 04:02:54.126096 139906365589376 tpu_estimator.py:2160] examples/sec: 4665.7
# I0710 04:02:54.129569 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:02:54.131247 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:03:05.111971 139906365589376 basic_session_run_hooks.py:260] loss = 7.646988, step = 5700 (10.990 sec)
# I0710 04:03:05.114488 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09933
# I0710 04:03:05.115971 139906365589376 tpu_estimator.py:2160] examples/sec: 4658.86
# I0710 04:03:05.119174 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:03:05.122418 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:03:16.115508 139906365589376 basic_session_run_hooks.py:260] loss = 7.2319794, step = 5800 (11.004 sec)
# I0710 04:03:16.117965 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08806
# I0710 04:03:16.119380 139906365589376 tpu_estimator.py:2160] examples/sec: 4653.09
# I0710 04:03:16.124944 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:03:16.126491 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:03:27.111098 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 5900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:03:33.173946 139906365589376 basic_session_run_hooks.py:260] loss = 6.23723, step = 5900 (17.058 sec)
# I0710 04:03:33.176435 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.86217
# I0710 04:03:33.179079 139906365589376 tpu_estimator.py:2160] examples/sec: 3001.43
# I0710 04:03:33.182287 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:03:33.184499 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:03:33.415570 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (59, 0)
# I0710 04:03:44.195240 139906365589376 basic_session_run_hooks.py:260] loss = 7.3956313, step = 6000 (11.021 sec)
# I0710 04:03:44.197636 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07345
# I0710 04:03:44.199071 139906365589376 tpu_estimator.py:2160] examples/sec: 4645.61
# I0710 04:03:44.202479 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:03:44.204281 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:03:55.187630 139906365589376 basic_session_run_hooks.py:260] loss = 6.44946, step = 6100 (10.992 sec)
# I0710 04:03:55.190498 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09683
# I0710 04:03:55.192022 139906365589376 tpu_estimator.py:2160] examples/sec: 4657.57
# I0710 04:03:55.197036 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:03:55.198670 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:04:06.172447 139906365589376 basic_session_run_hooks.py:260] loss = 7.023012, step = 6200 (10.985 sec)
# I0710 04:04:06.175167 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10359
# I0710 04:04:06.525708 139906365589376 tpu_estimator.py:2160] examples/sec: 4661.04
# I0710 04:04:06.533521 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:04:06.534888 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:04:17.527302 139906365589376 basic_session_run_hooks.py:260] loss = 5.491521, step = 6300 (11.355 sec)
# I0710 04:04:17.530059 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.80677
# I0710 04:04:17.532507 139906365589376 tpu_estimator.py:2160] examples/sec: 4509.07
# I0710 04:04:17.537732 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:04:17.540531 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:04:28.534197 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 6400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:04:35.164735 139906365589376 basic_session_run_hooks.py:260] loss = 6.394114, step = 6400 (17.637 sec)
# I0710 04:04:35.167617 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.66971
# I0710 04:04:35.169766 139906365589376 tpu_estimator.py:2160] examples/sec: 2902.89
# I0710 04:04:35.174422 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:04:35.175530 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:04:35.410515 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (64, 0)
# I0710 04:04:46.198675 139906365589376 basic_session_run_hooks.py:260] loss = 7.415154, step = 6500 (11.034 sec)
# I0710 04:04:46.201229 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.06324
# I0710 04:04:46.203706 139906365589376 tpu_estimator.py:2160] examples/sec: 4640.38
# I0710 04:04:46.208786 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:04:46.210527 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:04:57.177924 139906365589376 basic_session_run_hooks.py:260] loss = 6.8507934, step = 6600 (10.979 sec)
# I0710 04:04:57.180377 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10816
# I0710 04:04:57.181682 139906365589376 tpu_estimator.py:2160] examples/sec: 4663.38
# I0710 04:04:57.187786 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:04:57.189264 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:05:08.187896 139906365589376 basic_session_run_hooks.py:260] loss = 5.91856, step = 6700 (11.010 sec)
# I0710 04:05:08.190342 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.08269
# I0710 04:05:08.192013 139906365589376 tpu_estimator.py:2160] examples/sec: 4650.34
# I0710 04:05:08.195558 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:05:08.198457 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:05:19.141036 139906365589376 basic_session_run_hooks.py:260] loss = 6.4188037, step = 6800 (10.953 sec)
# I0710 04:05:19.143541 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.12975
# I0710 04:05:19.144709 139906365589376 tpu_estimator.py:2160] examples/sec: 4674.43
# I0710 04:05:19.147850 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:05:19.148616 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:05:30.124969 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 6900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:05:36.931469 139906365589376 basic_session_run_hooks.py:260] loss = 6.4899807, step = 6900 (17.790 sec)
# I0710 04:05:36.934390 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.62087
# I0710 04:05:36.936636 139906365589376 tpu_estimator.py:2160] examples/sec: 2877.89
# I0710 04:05:36.941302 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:05:36.942979 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:05:37.166476 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (69, 0)
# ...
# I0710 04:47:44.587773 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.44056
# I0710 04:47:44.590561 139906365589376 tpu_estimator.py:2160] examples/sec: 2785.56
# I0710 04:47:44.594835 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:47:44.596511 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:47:44.841796 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (274, 0)
# I0710 04:47:55.643920 139906365589376 basic_session_run_hooks.py:260] loss = 1.5122191, step = 27500 (11.059 sec)
# I0710 04:47:55.646538 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.0426
# I0710 04:47:55.650871 139906365589376 tpu_estimator.py:2160] examples/sec: 4629.81
# I0710 04:47:55.653556 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:47:55.655757 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:48:06.612190 139906365589376 basic_session_run_hooks.py:260] loss = 1.9371408, step = 27600 (10.968 sec)
# I0710 04:48:06.615258 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.11687
# I0710 04:48:06.618034 139906365589376 tpu_estimator.py:2160] examples/sec: 4667.84
# I0710 04:48:06.622743 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:48:06.623940 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:48:17.626534 139906365589376 basic_session_run_hooks.py:260] loss = 1.8864062, step = 27700 (11.014 sec)
# I0710 04:48:17.629127 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07948
# I0710 04:48:17.630290 139906365589376 tpu_estimator.py:2160] examples/sec: 4648.69
# I0710 04:48:17.634267 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:48:17.635989 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:48:28.580111 139906365589376 basic_session_run_hooks.py:260] loss = 1.0153985, step = 27800 (10.954 sec)
# I0710 04:48:28.582771 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.12938
# I0710 04:48:28.586222 139906365589376 tpu_estimator.py:2160] examples/sec: 4674.24
# I0710 04:48:28.590353 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:48:28.591907 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:48:39.558029 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 27900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:48:45.653084 139906365589376 basic_session_run_hooks.py:260] loss = 1.6030834, step = 27900 (17.073 sec)
# I0710 04:48:45.655766 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.85719
# I0710 04:48:45.658636 139906365589376 tpu_estimator.py:2160] examples/sec: 2998.88
# I0710 04:48:45.662319 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:48:45.663472 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:48:45.898813 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (279, 0)
# I0710 04:48:56.708576 139906365589376 basic_session_run_hooks.py:260] loss = 1.1460536, step = 28000 (11.056 sec)
# I0710 04:48:56.711009 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.04548
# I0710 04:48:56.712723 139906365589376 tpu_estimator.py:2160] examples/sec: 4631.29
# I0710 04:48:56.717242 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:48:56.718941 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:49:07.688913 139906365589376 basic_session_run_hooks.py:260] loss = 1.6325746, step = 28100 (10.980 sec)
# I0710 04:49:07.691758 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10683
# I0710 04:49:07.693852 139906365589376 tpu_estimator.py:2160] examples/sec: 4662.7
# I0710 04:49:07.701301 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:49:07.702725 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:49:18.713566 139906365589376 basic_session_run_hooks.py:260] loss = 1.4643226, step = 28200 (11.025 sec)
# I0710 04:49:18.716358 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07078
# I0710 04:49:19.049053 139906365589376 tpu_estimator.py:2160] examples/sec: 4644.24
# I0710 04:49:19.053679 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:49:19.054891 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:49:30.015369 139906365589376 basic_session_run_hooks.py:260] loss = 1.0594668, step = 28300 (11.302 sec)
# I0710 04:49:30.018490 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.8478
# I0710 04:49:30.020552 139906365589376 tpu_estimator.py:2160] examples/sec: 4530.08
# I0710 04:49:30.028763 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:49:30.034073 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:49:41.001599 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 28400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:49:46.729511 139906365589376 basic_session_run_hooks.py:260] loss = 1.2728552, step = 28400 (16.714 sec)
# I0710 04:49:46.731991 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.98317
# I0710 04:49:46.734456 139906365589376 tpu_estimator.py:2160] examples/sec: 3063.38
# I0710 04:49:46.739202 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:49:46.745041 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:49:46.979316 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (284, 0)
# I0710 04:49:57.724463 139906365589376 basic_session_run_hooks.py:260] loss = 1.6965289, step = 28500 (10.995 sec)
# I0710 04:49:57.726865 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09514
# I0710 04:49:57.728120 139906365589376 tpu_estimator.py:2160] examples/sec: 4656.71
# I0710 04:49:57.735724 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:49:57.736857 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:50:08.704189 139906365589376 basic_session_run_hooks.py:260] loss = 1.0956604, step = 28600 (10.980 sec)
# I0710 04:50:08.706752 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10755
# I0710 04:50:08.708054 139906365589376 tpu_estimator.py:2160] examples/sec: 4663.07
# I0710 04:50:08.711671 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:50:08.713500 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:50:19.681680 139906365589376 basic_session_run_hooks.py:260] loss = 1.123156, step = 28700 (10.977 sec)
# I0710 04:50:19.684251 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.10953
# I0710 04:50:19.686790 139906365589376 tpu_estimator.py:2160] examples/sec: 4664.08
# I0710 04:50:19.691324 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:50:19.693272 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:50:30.650156 139906365589376 basic_session_run_hooks.py:260] loss = 1.423388, step = 28800 (10.968 sec)
# I0710 04:50:30.652686 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.11707
# I0710 04:50:30.654008 139906365589376 tpu_estimator.py:2160] examples/sec: 4667.94
# I0710 04:50:30.657625 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:50:30.664469 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:50:41.629563 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 28900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:50:47.514407 139906365589376 basic_session_run_hooks.py:260] loss = 1.2915059, step = 28900 (16.864 sec)
# I0710 04:50:47.516838 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.92973
# I0710 04:50:47.517909 139906365589376 tpu_estimator.py:2160] examples/sec: 3036.02
# I0710 04:50:47.524433 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:50:47.526701 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:50:47.763478 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (289, 0)
# I0710 04:50:58.537618 139906365589376 basic_session_run_hooks.py:260] loss = 1.5438299, step = 29000 (11.023 sec)
# I0710 04:50:58.540134 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.07171
# I0710 04:50:58.541414 139906365589376 tpu_estimator.py:2160] examples/sec: 4644.72
# I0710 04:50:58.544054 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:50:58.545692 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:51:09.574229 139906365589376 basic_session_run_hooks.py:260] loss = 1.7101213, step = 29100 (11.037 sec)
# I0710 04:51:09.576781 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.06073
# I0710 04:51:09.581125 139906365589376 tpu_estimator.py:2160] examples/sec: 4639.09
# I0710 04:51:09.586253 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:51:09.588924 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:51:20.613733 139906365589376 basic_session_run_hooks.py:260] loss = 1.6650176, step = 29200 (11.040 sec)
# I0710 04:51:20.616288 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.05838
# I0710 04:51:21.104408 139906365589376 tpu_estimator.py:2160] examples/sec: 4637.89
# I0710 04:51:21.111437 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:51:21.113658 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:51:32.076322 139906365589376 basic_session_run_hooks.py:260] loss = 1.8409059, step = 29300 (11.463 sec)
# I0710 04:51:32.078628 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.72421
# I0710 04:51:32.079798 139906365589376 tpu_estimator.py:2160] examples/sec: 4466.79
# I0710 04:51:32.082106 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:51:32.083804 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:51:43.049259 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 29400 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:51:49.429894 139906365589376 basic_session_run_hooks.py:260] loss = 1.6059446, step = 29400 (17.354 sec)
# I0710 04:51:49.432783 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.76231
# I0710 04:51:49.436651 139906365589376 tpu_estimator.py:2160] examples/sec: 2950.3
# I0710 04:51:49.439924 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:51:49.441341 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:51:49.666388 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (294, 0)
# I0710 04:52:00.468910 139906365589376 basic_session_run_hooks.py:260] loss = 1.5431335, step = 29500 (11.039 sec)
# I0710 04:52:00.474043 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.05695
# I0710 04:52:00.476077 139906365589376 tpu_estimator.py:2160] examples/sec: 4637.16
# I0710 04:52:00.480068 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:52:00.481647 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:52:11.486620 139906365589376 basic_session_run_hooks.py:260] loss = 1.0979097, step = 29600 (11.018 sec)
# I0710 04:52:11.489326 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.0783
# I0710 04:52:11.490781 139906365589376 tpu_estimator.py:2160] examples/sec: 4648.09
# I0710 04:52:11.495402 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:52:11.497087 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:52:22.544561 139906365589376 basic_session_run_hooks.py:260] loss = 1.0962853, step = 29700 (11.058 sec)
# I0710 04:52:22.547111 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.04343
# I0710 04:52:22.548490 139906365589376 tpu_estimator.py:2160] examples/sec: 4630.23
# I0710 04:52:22.551857 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:52:22.554471 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:52:33.534735 139906365589376 basic_session_run_hooks.py:260] loss = 1.0518706, step = 29800 (10.990 sec)
# I0710 04:52:33.537312 139906365589376 tpu_estimator.py:2159] global_step/sec: 9.09898
# I0710 04:52:33.542234 139906365589376 tpu_estimator.py:2160] examples/sec: 4658.68
# I0710 04:52:33.547794 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:52:33.548840 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:52:44.503502 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 29900 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:52:50.935538 139906365589376 basic_session_run_hooks.py:260] loss = 1.2349405, step = 29900 (17.401 sec)
# I0710 04:52:50.938059 139906365589376 tpu_estimator.py:2159] global_step/sec: 5.74688
# I0710 04:52:50.939629 139906365589376 tpu_estimator.py:2160] examples/sec: 2942.4
# I0710 04:52:50.943783 139906365589376 tpu_estimator.py:590] Enqueue next (100) batch(es) of data to infeed.
# I0710 04:52:50.945214 139906365589376 tpu_estimator.py:594] Dequeue next (100) batch(es) of data from outfeed.
# I0710 04:52:51.175352 139905070257920 tpu_estimator.py:275] Outfeed finished for iteration (299, 0)
# I0710 04:53:02.099406 139906365589376 basic_session_run_hooks.py:260] loss = 1.2357823, step = 30000 (11.164 sec)
# I0710 04:53:02.102046 139906365589376 tpu_estimator.py:2159] global_step/sec: 8.95739
# I0710 04:53:02.105603 139906365589376 tpu_estimator.py:2160] examples/sec: 4586.18
# I0710 04:53:02.110378 139906365589376 basic_session_run_hooks.py:606] Saving checkpoints for 30000 into gs://kurnianggoro/training/testvgg/model.ckpt.
# I0710 04:53:07.997327 139906365589376 tpu_estimator.py:598] Stop infeed thread controller
# I0710 04:53:07.998564 139906365589376 tpu_estimator.py:430] Shutting down InfeedController thread.
# I0710 04:53:07.999848 139905078650624 tpu_estimator.py:425] InfeedController received shutdown signal, stopping.
# I0710 04:53:08.001027 139905078650624 tpu_estimator.py:530] Infeed thread finished, shutting down.
# I0710 04:53:08.006730 139906365589376 error_handling.py:96] infeed marked as finished
# I0710 04:53:08.009347 139906365589376 tpu_estimator.py:602] Stop output thread controller
# I0710 04:53:08.013657 139906365589376 tpu_estimator.py:430] Shutting down OutfeedController thread.
# I0710 04:53:08.016670 139905070257920 tpu_estimator.py:425] OutfeedController received shutdown signal, stopping.
# I0710 04:53:08.018525 139905070257920 tpu_estimator.py:541] Outfeed thread finished, shutting down.
# I0710 04:53:08.020866 139906365589376 error_handling.py:96] outfeed marked as finished
# I0710 04:53:08.023777 139906365589376 tpu_estimator.py:606] Shutdown TPU system.
# I0710 04:53:27.433447 139906365589376 estimator.py:368] Loss for final step: 1.2357823.
# I0710 04:53:27.435601 139906365589376 error_handling.py:96] training_loop marked as finished

# %% [markdown]
# #Dataset pipeline without tfrecord

# %%
dataset = tf.keras.datasets.cifar10

(x_train, y_train),(x_test, y_test) = dataset.load_data()
x_train, x_test = x_train / 255.0-0.5, x_test / 255.0-0.5

x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

def parser_fn(example):
    image = example['image']
    label = example['label']
    
    image = tf.cast(image, dtype=tf.float32)
    image = tf.reshape(image, [32,32,3])

    image = tf.image.resize_image_with_crop_or_pad(image, 40,40)
    image = tf.image.random_crop(image, [32,32,3])
    image = tf.reshape(image, [32,32,3])

        
    return image, tf.cast(label, tf.int64)

def input_pipeline(params):
    batch_size=10
    train=True
    
    x_data = tf.convert_to_tensor(x_train, name='x_data')
    y_data = tf.convert_to_tensor(y_train, name='y_data')

    dataset = tf.data.Dataset.from_tensor_slices({'image':x_data, 'label':y_data})

    dataset = dataset.shuffle(buffer_size=128)
    dataset = dataset.cache()
    if train:
        dataset = dataset.repeat()
    dataset = dataset.map(parser_fn,num_parallel_calls=8)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.make_one_shot_iterator()
    features, labels = dataset.get_next()

    return features, labels
